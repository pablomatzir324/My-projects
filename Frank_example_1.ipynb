# %% [markdown]
# <a href="https://colab.research.google.com/github/pablomatzir324/My-projects/blob/Disc-1/Frank_example_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install frank
# Out:
# Collecting frank
#   Downloading frank-1.2.3.tar.gz (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.12/dist-packages (from frank) (2.0.2)
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from frank) (3.10.0)
# Requirement already satisfied: scipy!=1.12.*,!=1.13.*,!=1.14.*,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from frank) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.0->frank) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.0->frank) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.0->frank) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.0->frank) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.0->frank) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.0->frank) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.0->frank) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.0->frank) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.0->frank) (1.17.0)
# Building wheels for collected packages: frank
#   Building wheel for frank (setup.py) ... done
#   Created wheel for frank: filename=frank-1.2.3-py3-none-any.whl size=88820 sha256=c9ca47d24bef9c3afcda1e82f510d8bc43ddd1b7a97beef0c8d7654b505fa7f8
#   Stored in directory: /root/.cache/pip/wheels/b5/99/ce/1182a492aaabf521672740b8918ff244d97e0c85b56bae82f8
# Successfully built frank
# Installing collected packages: frank
# Successfully installed frank-1.2.3

# %%
import matplotlib.pyplot as plt
import numpy as np
from frank.io import load_uvtable, save_fit
from frank.radial_fitters import FrankFitter
from frank.geometry import FitGeometryGaussian
from frank.make_figs import make_quick_fig

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
uvtable_filename = "/content/drive/MyDrive/Disco 1/J16120_Band7_keepflagsFalse.txt"
u, v, vis, weights = load_uvtable(uvtable_filename)

# %%
FF = FrankFitter(Rmax=1.6, N=250, geometry=FitGeometryGaussian(),
                 alpha=1.05, weights_smooth=1e-4)

sol = FF.fit(u, v, vis, weights)
# Out:
# /usr/local/lib/python3.12/dist-packages/frank/filter.py:175: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   tau = scipy.sparse.linalg.spsolve(Tij_pI, beta + np.log(pi))

# %%
fig, axes = make_quick_fig(u, v, vis, weights, sol, bin_widths=[1e3, 5e4], force_style=True)
plt.show()
